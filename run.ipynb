# %%
# !unzip V3.zip
# Out:
# Archive:  V3.zip
#   inflating: req.txt
#    creating: generated_images/
#    creating: generated_media/
#    creating: static/
#   inflating: static/script.js
#   inflating: static/styles.css
#    creating: templates/
#   inflating: templates/download.jpeg
#   inflating: templates/fashion_1746253158_0.png
#   inflating: templates/fashion_1746253165_1.png
#   inflating: templates/fashion_1746253173_2.png
#   inflating: templates/index.html
#   inflating: templates/upload-icon.svg
#    creating: uploads/
# replace main.py? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !pip install -r req.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 MB 11.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 113.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 63.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
# ...

# %%
# !python main.py
# Out:
# 2025-05-03 11:52:24.108852: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746273144.140728    2449 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746273144.151342    2449 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# جاري تحميل نموذج توليد الصور...
# model_index.json: 100% 541/541 [00:00<00:00, 3.45MB/s]
# Fetching 15 files:   0% 0/15 [00:00<?, ?it/s]
# model.safetensors:   0% 0.00/492M [00:00<?, ?B/s]
# model.safetensors:   6% 31.5M/492M [00:00<00:01, 250MB/s]
#
# config.json: 100% 4.72k/4.72k [00:00<00:00, 16.9MB/s]
#
#
# ...
